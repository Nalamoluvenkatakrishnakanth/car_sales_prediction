# %%
# Import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
import warnings
warnings.filterwarnings('ignore')

# %%
#read the dataset
sal_data = pd.read_csv(r"C:\Users\HP\Downloads\car_purchasing.csv",encoding="ISO-8859-1")  #here dataset is in bytes, so i have usen encoding
sal_data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %% [markdown]
# ### Undestandand and Preparing the data

# %%
sal_data.shape
# Out:
# (500, 9)

# %%
sal_data.dtypes
# Out:
# customer name           object
# customer e-mail         object
# country                 object
# gender                   int64
# age                    float64
# annual Salary          float64
# credit card debt       float64
# net worth              float64
# car purchase amount    float64
# dtype: object

# %%
sal_data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
sal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %% [markdown]
# #### Statistical analysis on dataset

# %%
#Numerical analysis
sal_data.describe(include='number')
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
#skewness for numerical columns
print(sal_data['car purchase amount'].skew())
print(sal_data['net worth'].skew())
print(sal_data['credit card debt'].skew())
print(sal_data['annual Salary'].skew())
# Out:
# -0.030790504601731758
# 0.13975524504816003
# -0.06372440430463279
# -0.08747828753379894

# %% [markdown]
# ### Observation
# 1.Genger is actually catagerical column,
#   but due to the presence of numerical data it got the misdatatype formatted
# 2.annual salary,credit card debt,net worth,car purchase ammount has a outliers and also data is present in float foramted ,
#   we need to convert into int formate
# 3. in age column data present in float formated we need to convert the data into int formate

# %%
ages=sal_data['age']
a=sal_data['annual Salary']
b=sal_data['credit card debt']
c=sal_data['net worth']
d=sal_data['car purchase amount']
sal_data['age']=[int(round(i)) for i in ages]
sal_data['annual Salary']=[int(round(i)) for i in a]
sal_data['credit card debt']=[int(round(i)) for i in b]
sal_data['net worth']=[int(round(i)) for i in c]
sal_data['car purchase amount']=[int(round(i)) for i in d]

sal_data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender  age  annual Salary  credit card debt  net worth  \
# ...

# %%
sal_data['gender']=sal_data['gender'].astype("object")
sal_data.dtypes
# Out:
# customer name          object
# customer e-mail        object
# country                object
# gender                 object
# age                     int64
# annual Salary           int64
# credit card debt        int64
# net worth               int64
# car purchase amount     int64
# dtype: object

# %%
#Categorical Analysis on dataset
cat_cols=list(sal_data.select_dtypes(include=['object']).columns)
cat_cols
# Out:
# ['customer name', 'customer e-mail', 'country']

# %%
#unique values of categorical data
for i in cat_cols:
    print(i,":- ",sal_data[i].unique(),"\n\n")
# Out:
# customer name :-  ['Martina Avila' 'Harlan Barnes' 'Naomi Rodriquez' 'Jade Cunningham'
#  'Cedric Leach' 'Carla Hester' 'Griffin Rivera' 'Orli Casey'
#  'Marny Obrien' 'Rhonda Chavez' 'Jerome Rowe' 'Akeem Gibson' 'Quin Smith'
#  'Tatum Moon' 'Sharon Sharpe' 'Thomas Williams' 'Blaine Bender'
#  'Stephen Lindsey' 'Sloane Mann' 'Athena Wolf' 'Blythe Romero'
#  'Zelenia Byers' 'Nola Wiggins' 'Micah Wheeler' 'Caryn Hendrix'
#  'Hedda Miranda' 'Ulric Lynn' 'Alma Pope' 'Gemma Hendrix' 'Castor Wood'
#  'Herman Stevenson' 'Adrienne Bolton' 'Dahlia Cleveland' 'Keane Browning'
#  'Quon Hull' 'Coby Charles' 'Amery Cortez' 'Uriel Bradshaw'
#  'Fredericka Sanders' 'Christopher Stevens' 'Rachel Ashley' 'Lael Wright'
#  'Ryder Shaffer' 'Eric Noel' 'Tamara Guy' 'Quincy Bell' 'Lee Taylor'
#  'Kenneth Pope' 'Reese Vance' 'Quon Carroll' 'Magee Davidson'
#  'Leilani Gross' 'Morgan William' 'Francesca Cervantes' 'Rafael Peterson'
#  'Roanna Knox' 'Marny Vargas' 'Charlotte Waller' 'Dorian Hernandez'
# ...

# %% [markdown]
# ### Observation
# 1. in gender column data is a hint of misformatting, it's showing 0's and 1's
#    we need to replace the values male and female inplace of  0's and 1's place

# %%
sal_data['gender'].replace(0,"male",inplace=True)
sal_data['gender'].replace(1,"female",inplace=True)

# %%
#catagerical
sal_data.describe(include='object')
# Out:
#        customer name                                    customer e-mail  \
# count            500                                                500
# unique           498                                                500
# top             Seth  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# freq               2                                                  1
#
#        country  gender
# count      500     500
# unique     211       2
# top     Israel  female
# freq         6     253

# %%
#missing value treatment
sal_data.isnull().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
# no missing values in the entaire dataset

# %%
sal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    object
#  4   age                  500 non-null    int64
#  5   annual Salary        500 non-null    int64
#  6   credit card debt     500 non-null    int64
#  7   net worth            500 non-null    int64
#  8   car purchase amount  500 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 35.3+ KB

# %% [markdown]
# ## Univarient Analysis
# Checking the outliers in each numerical column by using distplot and heatmap

# %%
sns.distplot(sal_data['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(sal_data['annual Salary'])
# Out:
# <Axes: xlabel='annual Salary', ylabel='Density'>

# %%
sns.distplot(sal_data['credit card debt'])
# Out:
# <Axes: xlabel='credit card debt', ylabel='Density'>

# %%
sns.distplot(sal_data['net worth'])
# Out:
# <Axes: xlabel='net worth', ylabel='Density'>

# %%
sns.distplot(sal_data['car purchase amount'])
# Out:
# <Axes: xlabel='car purchase amount', ylabel='Density'>

# %%
sal_data.select_dtypes(include='number').hist()
plt.tight_layout()

# %%
sal_data.drop(['car purchase amount','age'],axis=1).boxplot()
plt.xticks(rotation=60)
# Out:
# (array([1, 2, 3]),
#  [Text(1, 0, 'annual Salary'),
#   Text(2, 0, 'credit card debt'),
#   Text(3, 0, 'net worth')])

# %%
print(sns.boxplot(sal_data['credit card debt']))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
#  checking the outliers in categorical column using countplot

# %%
sns.countplot(data=sal_data, x='gender', palette="rainbow")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# ## Bivarient Analysis

# %% [markdown]
# numerical vs numerical column data using scatter plot and checking the correlation of all numerical columns using heatmap

# %%
df=sal_data.select_dtypes(include='number')
df
# Out:
#      age  annual Salary  credit card debt  net worth  car purchase amount
# 0     42          62812             11609     238961                35321
# 1     41          66647              9573     530974                45116
# 2     43          53799             11160     638467                42926
# 3     58          79370             14426     548599                67422
# 4     57          59729              5359     560304                55915
# ..   ...            ...               ...        ...                  ...
# 495   41          71942              6996     541670                48901
# 496   38          56039             12301     360419                31491
# 497   54          68889             10612     764531                64147
# 498   59          49812             14013     337827                45442
# 499   47          61371              9391     462946                45107
#
# [500 rows x 5 columns]

# %%
#checking the correlation between the numerical columns
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['age'], y=df['annual Salary'])
# Out:
# <Axes: xlabel='age', ylabel='annual Salary'>

# %%
sns.scatterplot(x=df['age'], y=df['credit card debt'])
# Out:
# <Axes: xlabel='age', ylabel='credit card debt'>

# %%
sns.scatterplot(x=df['age'], y=df['net worth'])
# Out:
# <Axes: xlabel='age', ylabel='net worth'>

# %% [markdown]
# ## Multivarient Analysis

# %% [markdown]
#  Numerical vs Numerical column finding the correlation between the columns usind heatmap

# %%
sal_data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
numerical=['age','annual Salary','credit card debt','net worth','car purchase amount']
plt.figure(figsize=(8, 5))
sns.heatmap(sal_data[numerical].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(sal_data[numerical])
plt.show()

# %% [markdown]
# Numerical vs Categorical

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="gender", y="net worth", data=sal_data)
plt.xticks(rotation=45)  # Rotate labels for readability
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="gender", y="car purchase amount", data=sal_data)
plt.xticks(rotation=45)  # Rotate labels for readability
plt.title("Car Purchase Sales")
plt.show()

# %% [markdown]
# ## Feature selection

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
X=df.select_dtypes(include='number')
sal_data_vif = pd.DataFrame()
sal_data_vif['Features'] = X.columns
sal_data_vif['VIF'] = [VIF(X, i) for i in range(len(X.columns))]
sal_data_vif
# Out:
#               Features        VIF
# 0                  age  37.048483
# 1        annual Salary  34.907620
# 2     credit card debt   8.628374
# 3            net worth  10.631296
# 4  car purchase amount  86.224479

# %%
sal_data.isnull().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %% [markdown]
# ## Final processing of the data to be feed into model

# %%
df = pd.get_dummies(sal_data, drop_first= True)
df.head()
# Out:
#    age  annual Salary  credit card debt  net worth  car purchase amount  \
# 0   42          62812             11609     238961                35321
# 1   41          66647              9573     530974                45116
# 2   43          53799             11160     638467                42926
# 3   58          79370             14426     548599                67422
# 4   57          59729              5359     560304                55915
#
#    customer name_Abigail X. Lindsey  customer name_Abra D. Golden  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
#
#    customer name_Adria Mathis  customer name_Adrian Brock  \
# 0                       False                       False
# ...

# %% [markdown]
# ## Feature transformation

# %%
# Before transformation y values
y= df['car purchase amount']
y
# Out:
# 0      35321
# 1      45116
# 2      42926
# 3      67422
# 4      55915
#        ...
# 495    48901
# 496    31491
# 497    64147
# 498    45442
# 499    45107
# Name: car purchase amount, Length: 500, dtype: int64

# %%
# Transforming Target Variable
y_trans = np.log(df['car purchase amount'])
y_trans
# Out:
# 0      10.472233
# 1      10.716992
# 2      10.667233
# 3      11.118727
# 4      10.931588
#          ...
# 495    10.797553
# 496    10.357457
# 497    11.068933
# 498    10.724192
# 499    10.716793
# Name: car purchase amount, Length: 500, dtype: float64

# %%
sns.distplot(df['car purchase amount'])
# Out:
# <Axes: xlabel='car purchase amount', ylabel='Density'>

# %%
# Feature Scaling on X
x = df.drop(columns=["car purchase amount"])
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scale = scaler.fit_transform(x)
x_scale
# Out:
# array([[-5.29167839e-01,  5.85696970e-02,  5.74163656e-01, ...,
#         -4.47661481e-02, -7.76930969e-02,  1.01207287e+00],
#        [-6.54444316e-01,  3.86580801e-01, -9.93892426e-03, ...,
#         -4.47661481e-02, -7.76930969e-02,  1.01207287e+00],
#        [-4.03891362e-01, -7.12320546e-01,  4.45351250e-01, ...,
#         -4.47661481e-02, -7.76930969e-02, -9.88071144e-01],
#        ...,
#        [ 9.74149886e-01,  5.78341139e-01,  2.88136999e-01, ...,
#         -4.47661481e-02, -7.76930969e-02, -9.88071144e-01],
#        [ 1.60053227e+00, -1.05333235e+00,  1.26384077e+00, ...,
#         -4.47661481e-02, -7.76930969e-02, -9.88071144e-01],
#        [ 9.72145462e-02, -6.46803685e-02, -6.21524162e-02, ...,
#          2.23383079e+01, -7.76930969e-02, -9.88071144e-01]])

# %%
# Target Variable
y= df['car purchase amount']

# Independent Variables
x = df.drop(columns=['car purchase amount'])

# %% [markdown]
# # Modeling with ML algorithm and with out transformation

# %% [markdown]
# ## Linear regression model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scale, y_trans, test_size= 0.2, random_state=100)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

model_lr = LinearRegression()
model_lr
# Out:
# LinearRegression()

# %%
#Assign linearregression model

model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=model_lr.predict(x_train)
y_test_pred=model_lr.predict(x_test)

# %%
#train data
print("mae:",mean_absolute_error(y_train, y_train_pred))
print("rmse_train:",np.sqrt(mean_squared_error(y_train, y_train_pred)))
print("R2_score_train",r2_score(y_train, y_train_pred))
# Out:
# mae: 6.217248937900876e-16
# rmse_train: 1.1234667099445444e-15
# R2_score_train 1.0

# %%
#test data
print("mae:",mean_absolute_error(y_test, y_test_pred))
print("rmse_test:",np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("R2_score_test",r2_score(y_test, y_test_pred))
# Out:
# mae: 0.17451628324459872
# rmse_test: 0.2646363947086046
# R2_score_test 0.34873467109244116

# %% [markdown]
# ## Modeling with ML Algorithm and with transformation

# %%
from sklearn.model_selection import train_test_split
x_train_sc,x_test_sc,y_train_sc,y_test_sc=train_test_split(x_scale,y_trans,test_size=0.25,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
lr=LinearRegression()
lr.fit(x_train_sc,y_train_sc)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(x_train_sc)
y_test_pred=lr.predict(x_test_sc)

# %%
r2_test=r2_score(y_test_sc,y_test_pred)
r2_train=r2_score(y_train_sc,y_train_pred)

# %%
#calculate rmse as a measure of accuracy
rmse_train=np.sqrt(mean_squared_error(y_train_sc,y_train_pred))
rmse_test=np.sqrt(mean_squared_error(y_test_sc,y_test_pred))

# %%
#calculate mae as ameasure of accuracy
mae=mean_absolute_error(y_test_sc,y_test_pred)

# %%
#Print the accuracy metrics
#print("MAE :",mae)
print("RMSE_train:",rmse_train)
print("RMSE_test:",rmse_test)
print("R2 score train :",r2_train)
print("R2 score test :",r2_test)
# Out:
# RMSE_train: 1.5914676914815441e-15
# RMSE_test: 0.25727997487470755
# R2 score train : 1.0
# R2 score test : 0.33325873224916647
